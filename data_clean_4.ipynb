# %%
import pandas as pd

# %%
df = pd.read_csv('data\gsc_shipping_rates.csv')

# %%
df.head(10)
# Out:
#       date  year  month  baltic_dry_index  container_rate_usd_40ft  \
# 0  2000-01  2000      1              1239                     1630
# 1  2000-02  2000      2              1210                     1810
# 2  2000-03  2000      3              1286                     1660
# 3  2000-04  2000      4              1216                     2050
# 4  2000-05  2000      5              1316                     1900
# 5  2000-06  2000      6              1391                     1800
# 6  2000-07  2000      7              1265                     1870
# 7  2000-08  2000      8              1339                     1890
# 8  2000-09  2000      9              1328                     2130
# 9  2000-10  2000     10              1416                     1980
#
#    air_cargo_rate_usd_kg  bdi_mom_change_pct  container_yoy_pct  \
# 0                   3.40                 NaN                NaN
# 1                   3.00               -2.34                NaN
# ...

# %%
#check for null values
df.isnull().sum()
# Out:
# date                               0
# year                               0
# month                              0
# baltic_dry_index                   0
# container_rate_usd_40ft            0
# air_cargo_rate_usd_kg              0
# bdi_mom_change_pct                 1
# container_yoy_pct                 12
# tanker_rate_aframax_usd_day        0
# bulk_carrier_handysize_usd_day     0
# supply_chain_pressure_index        0
# on_time_delivery_pct               0
# dtype: int64

# %%
df.head(20)
# Out:
#        date  year  month  baltic_dry_index  container_rate_usd_40ft  \
# 0   2000-01  2000      1              1239                     1630
# 1   2000-02  2000      2              1210                     1810
# 2   2000-03  2000      3              1286                     1660
# 3   2000-04  2000      4              1216                     2050
# 4   2000-05  2000      5              1316                     1900
# 5   2000-06  2000      6              1391                     1800
# 6   2000-07  2000      7              1265                     1870
# 7   2000-08  2000      8              1339                     1890
# 8   2000-09  2000      9              1328                     2130
# 9   2000-10  2000     10              1416                     1980
# 10  2000-11  2000     11              1281                     1650
# 11  2000-12  2000     12              1413                     1970
# 12  2001-01  2001      1              1319                     1950
# ...

# %%
#remove rows with null values
df = df.dropna()

# %%
df.head(10)
# Out:
#        date  year  month  baltic_dry_index  container_rate_usd_40ft  \
# 12  2001-01  2001      1              1319                     1950
# 13  2001-02  2001      2              1425                     1780
# 14  2001-03  2001      3              1485                     1700
# 15  2001-04  2001      4              1449                     1700
# 16  2001-05  2001      5              1431                     1620
# 17  2001-06  2001      6              1479                     1690
# 18  2001-07  2001      7              1656                     1670
# 19  2001-08  2001      8              1513                     1630
# 20  2001-09  2001      9              1589                     1710
# 21  2001-10  2001     10              1553                     2100
#
#     air_cargo_rate_usd_kg  bdi_mom_change_pct  container_yoy_pct  \
# 12                   3.13               -6.65              19.63
# 13                   3.24                8.04              -1.66
# ...

# %%
#df to csv
df.to_csv('data_usable\gsc_shipping_rates_clean.csv', index=False)
