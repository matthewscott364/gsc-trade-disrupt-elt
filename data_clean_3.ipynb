# %%
import pandas as pd

# %%
df = pd.read_csv('data\gsc_industry_exposure.csv')

# %%
df.head(10)
# Out:
#    year        industry  pandemic_exposure  geopolitical_exposure  \
# 0  2000  Semiconductors                9.0                   10.4
# 1  2001  Semiconductors                9.1                   10.0
# 2  2002  Semiconductors                9.3                   10.5
# 3  2003  Semiconductors                9.5                   10.1
# 4  2004  Semiconductors                9.3                   10.1
# 5  2005  Semiconductors                9.0                   10.2
# 6  2006  Semiconductors                8.9                    9.9
# 7  2007  Semiconductors                9.5                    9.6
# 8  2008  Semiconductors                9.1                   10.3
# 9  2009  Semiconductors                9.2                   10.4
#
#    natural_disaster_exposure  tariff_exposure  logistics_exposure  \
# 0                        7.8              8.8                 6.9
# 1                        8.3              9.4                 7.2
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# year                          0
# industry                      0
# pandemic_exposure             0
# geopolitical_exposure         0
# natural_disaster_exposure     0
# tariff_exposure               0
# logistics_exposure            0
# energy_exposure               0
# labor_exposure                0
# cyber_exposure                0
# overall_vulnerability         0
# inventory_days                0
# supplier_concentration_hhi    0
# just_in_time_dependency       0
# nearshoring_score_2024        0
# dtype: int64
