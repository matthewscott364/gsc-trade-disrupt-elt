# %%
import pandas as pd

# %%
df = pd.read_csv('data\gsc_congestion.csv')

# %%
df.head(15)
# Out:
#     week_start  year      port country region  throughput_teu_mn  \
# 0   2019-01-07  2019  Shanghai   China   Asia                 95
# 1   2019-01-14  2019  Shanghai   China   Asia                 95
# 2   2019-01-21  2019  Shanghai   China   Asia                 95
# 3   2019-01-28  2019  Shanghai   China   Asia                 95
# 4   2019-02-04  2019  Shanghai   China   Asia                 95
# 5   2019-02-11  2019  Shanghai   China   Asia                 95
# 6   2019-02-18  2019  Shanghai   China   Asia                 95
# 7   2019-02-25  2019  Shanghai   China   Asia                 95
# 8   2019-03-04  2019  Shanghai   China   Asia                 95
# 9   2019-03-11  2019  Shanghai   China   Asia                 95
# 10  2019-03-18  2019  Shanghai   China   Asia                 95
# 11  2019-03-25  2019  Shanghai   China   Asia                 95
# 12  2019-04-01  2019  Shanghai   China   Asia                 95
# ...

# %%
#check for nulls
df.isnull().sum()
# Out:
# week_start              0
# year                    0
# port                    0
# country                 0
# region                  0
# throughput_teu_mn       0
# vessels_at_anchor       0
# avg_wait_days           0
# congestion_index        0
# port_utilization_pct    0
# berth_delay_hrs         0
# dtype: int64
