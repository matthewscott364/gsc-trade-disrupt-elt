# %%
import pandas as pd

# %%
df = pd.read_csv('data\gsc_trade_flows.csv')

# %%
df.head(10)
# Out:
#    year   exporter importer trade_category          key_goods  \
# 0  2000  Australia    China    commodities  iron ore,coal,LNG
# 1  2001  Australia    China    commodities  iron ore,coal,LNG
# 2  2002  Australia    China    commodities  iron ore,coal,LNG
# 3  2003  Australia    China    commodities  iron ore,coal,LNG
# 4  2004  Australia    China    commodities  iron ore,coal,LNG
# 5  2005  Australia    China    commodities  iron ore,coal,LNG
# 6  2006  Australia    China    commodities  iron ore,coal,LNG
# 7  2007  Australia    China    commodities  iron ore,coal,LNG
# 8  2008  Australia    China    commodities  iron ore,coal,LNG
# 9  2009  Australia    China    commodities  iron ore,coal,LNG
#
#    trade_value_bn_usd  yoy_growth_pct  effective_tariff_rate_pct  \
# 0               23.18             NaN                        2.5
# 1               26.71           15.23                        2.5
# 2               26.44           -1.01                        2.5
# ...

# %%
df.isna().sum()
# Out:
# year                          0
# exporter                      0
# importer                      0
# trade_category                0
# key_goods                     0
# trade_value_bn_usd            0
# yoy_growth_pct               50
# effective_tariff_rate_pct     0
# trade_active                  0
# supply_chain_integrated       0
# concentration_risk            0
# dtype: int64

# %%
#drop nulls in 'yoy_growth_pct' column
df = df.dropna(subset=['yoy_growth_pct'])

# %%
df.isnull().sum()
# Out:
# year                         0
# exporter                     0
# importer                     0
# trade_category               0
# key_goods                    0
# trade_value_bn_usd           0
# yoy_growth_pct               0
# effective_tariff_rate_pct    0
# trade_active                 0
# supply_chain_integrated      0
# concentration_risk           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 1 to 1249
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       1200 non-null   int64
#  1   exporter                   1200 non-null   object
#  2   importer                   1200 non-null   object
#  3   trade_category             1200 non-null   object
#  4   key_goods                  1200 non-null   object
#  5   trade_value_bn_usd         1200 non-null   float64
#  6   yoy_growth_pct             1200 non-null   float64
#  7   effective_tariff_rate_pct  1200 non-null   float64
#  8   trade_active               1200 non-null   int64
#  9   supply_chain_integrated    1200 non-null   int64
#  10  concentration_risk         1200 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 112.5+ KB

# %%
df.to_csv('data_usable\gsc_trade_flows_clean.csv', index=False)
