# %%
import pandas as pd

# %%
df = pd.read_csv('data\gsc_disruption_events.csv')

# %%
df.head(10)
# Out:
#          date  year                                      event_name  \
# 0  2001-09-11  2001                 9/11 attacks — air cargo freeze
# 1  2002-10-01  2002               US West Coast port lockout (ILWU)
# 2  2003-04-01  2003           SARS outbreak — Asia trade disruption
# 3  2004-01-01  2004     China manufacturing surge — capacity crunch
# 4  2005-08-29  2005        Hurricane Katrina — Gulf of Mexico ports
# 5  2008-09-15  2008           Lehman collapse — global trade freeze
# 6  2010-04-15  2010      Eyjafjallajökull eruption — air cargo halt
# 7  2011-03-11  2011  Tohoku earthquake/tsunami — Japan supply shock
# 8  2011-08-01  2011           Thailand floods — HDD supply collapse
# 9  2012-06-01  2012     Euro debt crisis — Mediterranean trade drop
#
#   disruption_type region_affected  duration_days  bdi_shock_pct  \
# 0    geopolitical          Global             30            -15
# 1           labor    NorthAmerica             11             -5
# ...

# %%
#check for nulls
df.isnull().sum()
# Out:
# date                       0
# year                       0
# event_name                 0
# disruption_type            0
# region_affected            0
# duration_days              0
# bdi_shock_pct              0
# freight_rate_shock_pct     0
# severity                   0
# gdp_impact_pct             0
# trade_volume_impact_pct    0
# recovery_months            0
# is_pandemic                0
# is_geopolitical            0
# is_natural                 0
# is_financial               0
# straits_affected           0
# port_closure               0
# dtype: int64
